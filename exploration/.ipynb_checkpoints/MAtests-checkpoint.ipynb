# %%
import pandas as pd
        
import plotly.graph_objects as go
import datetime as dt
from plotting import CandlePlot

# %%
pair = "EUR_USD"
granularity = "H4"
df = pd.read_pickle(f"../data/{pair}_{granularity}.pkl")
MA_LIST = [10, 20, 50, 100, 200]

# %%
df.columns
# Out:
# Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c'],
#       dtype='object')

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head(10)
# Out:
#                        time    mid_o    mid_h    mid_l    mid_c     MA_10  \
# 0 2022-03-15 17:00:00+00:00  1.09514  1.09542  1.09261  1.09522  1.096593
# 1 2022-03-15 21:00:00+00:00  1.09538  1.09742  1.09486  1.09570  1.096597
# 2 2022-03-16 01:00:00+00:00  1.09570  1.09774  1.09560  1.09680  1.096699
# 3 2022-03-16 05:00:00+00:00  1.09680  1.10056  1.09559  1.09908  1.096865
# 4 2022-03-16 09:00:00+00:00  1.09906  1.10248  1.09800  1.09892  1.097357
# 5 2022-03-16 13:00:00+00:00  1.09891  1.10400  1.09856  1.10010  1.097863
# 6 2022-03-16 17:00:00+00:00  1.10010  1.10470  1.09500  1.10354  1.098392
# 7 2022-03-16 21:00:00+00:00  1.10360  1.10525  1.10078  1.10515  1.098869
# 8 2022-03-17 01:00:00+00:00  1.10514  1.10520  1.10299  1.10346  1.099311
# 9 2022-03-17 05:00:00+00:00  1.10346  1.10674  1.10222  1.10530  1.100327
#
#       MA_20     MA_50    MA_100    MA_200
# 0  1.096329  1.096056  1.109061  1.121642
# 1  1.096161  1.095868  1.108654  1.121551
# 2  1.096059  1.095673  1.108292  1.121462
# 3  1.096074  1.095556  1.107947  1.121384
# 4  1.096024  1.095477  1.107626  1.121302
# 5  1.096192  1.095451  1.107323  1.121236
# 6  1.096378  1.095704  1.107052  1.121169
# 7  1.097053  1.095955  1.106784  1.121119
# 8  1.097667  1.096149  1.106477  1.121062
# 9  1.098286  1.096568  1.106196  1.121010

# %%
for ma in MA_LIST:
    df_ma[f"MA_{ma}"] = df_ma.mid_c.rolling(window = ma).mean()

df_ma.dropna(inplace = True)
df_ma.reset_index(inplace = True, drop= True)

# %%
df_plot = df_ma.iloc[:500]
df_plot.shape
# Out:
# (500, 10)

# %%
traces = [ f"MA_{x}" for x in MA_LIST ]
traces
# Out:
# ['MA_10', 'MA_20', 'MA_50', 'MA_100', 'MA_200']

# %%
cp = CandlePlot(df_plot)

cp.show_plot(line_traces = traces)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[1, 2, 3, 4, 5],
    y=[1, 2, 3, 4, 5],
    name="Increasing"
))

# fig.add_trace(go.Scatter(
#     x=[1, 2, 3, 4, 5],
#     y=[5, 4, 3, 2, 1],
#     name="Decreasing"
# ))

fig.update_layout(legend_title_text='Trend')
fig.show()

# fig = go.Figure()
# fig.add_trace(go.Scatter(
#     x=[1, 2, 3, 4, 5],
#     y=[1, 2, 3, 4, 5],
#     name="Increasing",
# ))

# fig.show()
